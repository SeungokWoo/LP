# %% [markdown]
# ### Import libraries

# %%
import random
import string

# %% [markdown]
# ### Define functions
# * Any random word in certain length

# %%
def generate_word(length):
    result = ''
    
    x = ''.join(random.sample(string.ascii_letters + string.digits, k=length))
    # ascii_letters: 문자, digits: 숫자
    
    return x

# %% [markdown]
# * Population in given size and length

# %%
def generate_population(size, min_len, max_len):
    population = []
    
    for i in range(size):
        
        length = random.randint(min_len, max_len)
        # random.randint(a,b): a,b사이에서 랜덤으로 정수 추출
        
        population.append(generate_word(length))
        
    return population

# %% [markdown]
# * Fitness of the candidates

# %%
def fitness(password, test_word):
    score = 0

    if len(password) != len(test_word):
        return score
    
    else:
        len_score = 0.5
        score += len_score
        # 길이가 맞으면 0.5점 부여
        
        for i in range(len(password)):
            if password[i] == test_word[i]:
                score += 1
                # 문자와 위치가 맞으면 1점 부여

    return score / (len(password) + len_score) * 100

# %% [markdown]
# * Evaluate the performance of candidates

# %%
def compute_performace(population, password):
    performance_list = []
    
    for chromosome in population:
        score = fitness(password, chromosome)

        if score > 0:
            pred_len = len(chromosome)
        performance_list.append([chromosome, score])

    population_sorted = sorted(performance_list, key=lambda x: x[1], reverse=True)
    # sorted(a,b): a에서 b 기준으로 오름차순 (여기서는 score 기준으로 내림차순)
    return population_sorted, pred_len

# %% [markdown]
# * Selecting

# %%
def select_survivors(population_sorted, best_sample, lucky_sample, password_len):
    next_generation = []

    for i in range(best_sample):
        if population_sorted[i][1] > 0:
            next_generation.append(population_sorted[i][0])
            # population_sorted에서 가장 점수가 높은 chromosome을 best_sample만큼 가져옴

    lucky_survivors = random.sample(population_sorted, k=lucky_sample)
    # random.sample(a,b): a에서 b개를 랜덤으로 추출
    
    for i in lucky_survivors:
        next_generation.append(i[0])
        # 운좋게 살아남은 survivors 추가
        
    while len(next_generation) < best_sample + lucky_sample:
        next_generation.append(generate_word(length=password_len))
        # 다음 세대의 수가 부족하다면 새로운 개체 추가

    random.shuffle(next_generation)
    return next_generation

# %% [markdown]
# * Uniform

# %%
def create_child(chromosome1, chromosome2):
    child = ''
    min_len_chro = min(len(chromosome1), len(chromosome2))
    
    for i in range(min_len_chro):
        
        if (int(100 * random.random()) < 50):
            child += chromosome1[i]
        else:
            child += chromosome2[i]
        # 50%의 확률로 부모 중 하나를 따라감
            
    return child

# %%
def create_children(parents, num_child):
    next_population = []
    
    for i in range(int(len(parents)/2)):
        # 부모 수/2 = 커플 쌍
        
        for j in range(num_child):
            next_population.append(create_child(parents[i], parents[len(parents) - 1 - i]))
            # 각 커플쌍마다 num_child 만큼의 자녀 생성
            
    return next_population

# %% [markdown]
# * Mutation

# %%
def mutate_word(word):
    idx = int(random.random() * len(word))
    
    if (idx == 0):
        word = random.choice(string.ascii_letters + string.digits) + word[1:]
        
    else:
        word = word[:idx] + random.choice(string.ascii_letters + string.digits) + word[idx+1:]
        # 임의로 한자리를 랜덤한 문자/숫자로 변경
        
    return word

# %%
def mutate_population(population, chance_of_mutation):
    
    for i in range(len(population)):
        
        if random.random() * 100 < chance_of_mutation:
            population[i] = mutate_word(population[i])
            # 설정한 mutation 비율만큼 돌연변이 생성
            
    return population

# %% [markdown]
# #### Test

# %%
password = '1HanDong1'
min_len = 2
max_len = 10
n_generation = 300
population = 100
best_sample = 20
lucky_sample = 20
num_child = 5
chance_of_mutation = 10

pop = generate_population(size=population, min_len=min_len, max_len=max_len)

for g in range(n_generation):
    pop_sorted, pred_len = compute_performace(population=pop, password=password)

    if int(pop_sorted[0][1]) == 100:
        print('SUCCESS! The password is %s' % (pop_sorted[0][0]))
        break
    
    survivors = select_survivors(population_sorted=pop_sorted, best_sample=best_sample, lucky_sample=lucky_sample, password_len=pred_len)
    print("Password length must be",pred_len)
    
    children = create_children(parents=survivors, num_child=num_child)

    new_generation = mutate_population(population=children, chance_of_mutation=10)
    
    pop = new_generation
    
    print('===== %sth Generation =====' % (g + 1))
    print(pop_sorted[0])
# Out:
# Password length must be 9
# ===== 1th Generation =====
# ['jaPdg9Ick', 5.263157894736842]
# Password length must be 9
# ===== 2th Generation =====
# ['RNVz2oFLE', 15.789473684210526]
# Password length must be 9
# ===== 3th Generation =====
# ['RNQJ2o9cE', 15.789473684210526]
# Password length must be 9
# ===== 4th Generation =====
# ['1LQIhd63E', 15.789473684210526]
# Password length must be 9
# ===== 5th Generation =====
# ['3ERJboxDr', 15.789473684210526]
# Password length must be 9
# ===== 6th Generation =====
# ['1dQIbo6xE', 26.31578947368421]
# Password length must be 9
# ===== 7th Generation =====
# ['1NQFho62E', 26.31578947368421]
# Password length must be 9
# ===== 8th Generation =====
# ['3EQFDo6DE', 26.31578947368421]
# Password length must be 9
# ===== 9th Generation =====
# ['1NQIro67r', 26.31578947368421]
# Password length must be 9
# ===== 10th Generation =====
# ['1NQIDo67r', 36.84210526315789]
# Password length must be 9
# ===== 11th Generation =====
# ['1NQFDo62E', 36.84210526315789]
# Password length must be 9
# ===== 12th Generation =====
# ['1NQIDo63E', 36.84210526315789]
# Password length must be 9
# ===== 13th Generation =====
# ['1NnbDo97E', 36.84210526315789]
# Password length must be 9
# ===== 14th Generation =====
# ['1dQIDo97E', 36.84210526315789]
# Password length must be 9
# ===== 15th Generation =====
# ['1dQFDo97E', 36.84210526315789]
# Password length must be 9
# ===== 16th Generation =====
# ['1NQFDoT7E', 36.84210526315789]
# Password length must be 9
# ===== 17th Generation =====
# ['1NQnDo67E', 47.368421052631575]
# Password length must be 9
# ===== 18th Generation =====
# ['1NQnDo62E', 47.368421052631575]
# Password length must be 9
# ===== 19th Generation =====
# ['1NQnDo67E', 47.368421052631575]
# Password length must be 9
# ===== 20th Generation =====
# ['1NQnDo63E', 47.368421052631575]
# Password length must be 9
# ===== 21th Generation =====
# ['1NQnDo63E', 47.368421052631575]
# Password length must be 9
# ===== 22th Generation =====
# ['1dcnDo63E', 47.368421052631575]
# Password length must be 9
# ===== 23th Generation =====
# ['1NcnDoT31', 57.89473684210527]
# Password length must be 9
# ===== 24th Generation =====
# ['1NQnDoT31', 57.89473684210527]
# Password length must be 9
# ===== 25th Generation =====
# ['1NQnDo631', 57.89473684210527]
# Password length must be 9
# ===== 26th Generation =====
# ['1HQnDo67E', 57.89473684210527]
# Password length must be 9
# ===== 27th Generation =====
# ['1NQnDo631', 57.89473684210527]
# Password length must be 9
# ===== 28th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 29th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 30th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 31th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 32th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 33th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 34th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 35th Generation =====
# ['1HQnDo671', 68.42105263157895]
# Password length must be 9
# ===== 36th Generation =====
# ['1HQnDo671', 68.42105263157895]
# Password length must be 9
# ===== 37th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 38th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 39th Generation =====
# ['1HenDoT71', 68.42105263157895]
# Password length must be 9
# ===== 40th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 41th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 42th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 43th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 44th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 45th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 46th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 47th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 48th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 49th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 50th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 51th Generation =====
# ['1HQnDom71', 68.42105263157895]
# Password length must be 9
# ===== 52th Generation =====
# ['1HQnDoTv1', 68.42105263157895]
# Password length must be 9
# ===== 53th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 54th Generation =====
# ['1HFnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 55th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 56th Generation =====
# ['1HFnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 57th Generation =====
# ['1HQnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 58th Generation =====
# ['1HFnDom31', 68.42105263157895]
# Password length must be 9
# ===== 59th Generation =====
# ['1HQnDos31', 68.42105263157895]
# Password length must be 9
# ===== 60th Generation =====
# ['1HFnDom31', 68.42105263157895]
# Password length must be 9
# ===== 61th Generation =====
# ['1HQnDos71', 68.42105263157895]
# Password length must be 9
# ===== 62th Generation =====
# ['1HFnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 63th Generation =====
# ['1HFnDoE31', 68.42105263157895]
# Password length must be 9
# ===== 64th Generation =====
# ['1HFnDos31', 68.42105263157895]
# Password length must be 9
# ===== 65th Generation =====
# ['1HFnDos71', 68.42105263157895]
# Password length must be 9
# ===== 66th Generation =====
# ['1HFnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 67th Generation =====
# ['1HQnDos31', 68.42105263157895]
# Password length must be 9
# ===== 68th Generation =====
# ['1HFnDos31', 68.42105263157895]
# Password length must be 9
# ===== 69th Generation =====
# ['1HQnDos31', 68.42105263157895]
# Password length must be 9
# ===== 70th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 71th Generation =====
# ['1HQnDos31', 68.42105263157895]
# Password length must be 9
# ===== 72th Generation =====
# ['1HFnDoT71', 68.42105263157895]
# Password length must be 9
# ===== 73th Generation =====
# ['1HQnDoTR1', 68.42105263157895]
# Password length must be 9
# ===== 74th Generation =====
# ['1HFnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 75th Generation =====
# ['1HFnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 76th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 77th Generation =====
# ['1HFnDoi71', 68.42105263157895]
# Password length must be 9
# ===== 78th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 79th Generation =====
# ['1HFnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 80th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 81th Generation =====
# ['1HQnDoTT1', 68.42105263157895]
# Password length must be 9
# ===== 82th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 83th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 84th Generation =====
# ['1HQnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 85th Generation =====
# ['1HVnDorT1', 68.42105263157895]
# Password length must be 9
# ===== 86th Generation =====
# ['1HVnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 87th Generation =====
# ['1HVnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 88th Generation =====
# ['1HVnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 89th Generation =====
# ['1HVnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 90th Generation =====
# ['1H8nDoT31', 68.42105263157895]
# Password length must be 9
# ===== 91th Generation =====
# ['1HVnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 92th Generation =====
# ['1HVnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 93th Generation =====
# ['1HVnDoT31', 68.42105263157895]
# Password length must be 9
# ===== 94th Generation =====
# ['1HFnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 95th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 96th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 97th Generation =====
# ['1HQnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 98th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 99th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 100th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 101th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 102th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 103th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 104th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 105th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 106th Generation =====
# ['1HhnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 107th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 108th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 109th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 110th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 111th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 112th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 113th Generation =====
# ['1HVnDolg1', 78.94736842105263]
# Password length must be 9
# ===== 114th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 115th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 116th Generation =====
# ['1HanDoTg1', 89.47368421052632]
# Password length must be 9
# ===== 117th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 118th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 119th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 120th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 121th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 122th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 123th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 124th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 125th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 126th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 127th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 128th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 129th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 130th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 131th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 132th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 133th Generation =====
# ['1HVnDomg1', 78.94736842105263]
# Password length must be 9
# ===== 134th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 135th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 136th Generation =====
# ['1HVnDomg1', 78.94736842105263]
# Password length must be 9
# ===== 137th Generation =====
# ['1HVnDomg1', 78.94736842105263]
# Password length must be 9
# ===== 138th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 139th Generation =====
# ['1HVnDomg1', 78.94736842105263]
# Password length must be 9
# ===== 140th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 141th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 142th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 143th Generation =====
# ['1HBnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 144th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 145th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 146th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 147th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 148th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 149th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 150th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 151th Generation =====
# ['1HVnDoTg1', 78.94736842105263]
# Password length must be 9
# ===== 152th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 153th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 154th Generation =====
# ['1HVnDopg1', 78.94736842105263]
# Password length must be 9
# ===== 155th Generation =====
# ['1HanDopg1', 89.47368421052632]
# Password length must be 9
# ===== 156th Generation =====
# ['1HanDopg1', 89.47368421052632]
# Password length must be 9
# ===== 157th Generation =====
# ['1HanDoTg1', 89.47368421052632]
# Password length must be 9
# ===== 158th Generation =====
# ['1HanDoTg1', 89.47368421052632]
# Password length must be 9
# ===== 159th Generation =====
# ['1HanDopg1', 89.47368421052632]
# Password length must be 9
# ===== 160th Generation =====
# ['1HanDopg1', 89.47368421052632]
# Password length must be 9
# ===== 161th Generation =====
# ['1HanDoXg1', 89.47368421052632]
# Password length must be 9
# ===== 162th Generation =====
# ['1HanDoXg1', 89.47368421052632]
# Password length must be 9
# ===== 163th Generation =====
# ['1HanDoXg1', 89.47368421052632]
# Password length must be 9
# ===== 164th Generation =====
# ['1HanDoeg1', 89.47368421052632]
# Password length must be 9
# ===== 165th Generation =====
# ['1HanDopg1', 89.47368421052632]
# Password length must be 9
# ===== 166th Generation =====
# ['1HanDopg1', 89.47368421052632]
# SUCCESS! The password is 1HanDong1
